# %%
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Graph import Graph
from topologicpy.Helper import Helper

# %% [markdown]
# #Pattern.py

# %%
#somthing.Do thing(input)   return new topology
v1 = Vertex.ByCoordinates(0,0,0)
v2 = Vertex.ByCoordinates(1,0,0)
e1=Edge.ByStartVertexEndVertex(v1,v2)

# %% [markdown]
# ## 3. Set your renderer:
# * Visual studio code: "vscode"
# * Google Colab: "colab"
# * Browser: "browser"

# %%
renderer = "vscode"

# %%
Topology.Show(e1,
              backgroundColor="white",
              width=1000,
              height=1000,
              renderer=renderer)

# %% [markdown]
# # Cass name.Method name(inputs).----- this is 90% of the library

# %% [markdown]
# # PYTHON  YOU NEED

# %%
#LIST 
faces = ["face1", "face2", "face3"] # list of 3 faces
faces[0] # first face (zero-indexed!)
faces[-1] # last face
faces.append("face4") # add to the end
len(faces) # how many items → 
print(faces[1])
print(len(faces))
print(faces)
# Out:
# face2
# 4
# ['face1', 'face2', 'face3', 'face4']

# %%
#Tuple
point = (10.0, 5.0, 0.0) # x, y, z
x, y, z = point # unpacking — three names at onc
print(point)
# Out:
# (10.0, 5.0, 0.0)

# %%
#04_dicts.py
room = {"name": "Kitchen", "area": 18.5, "floor": 1}
room["name"] # → "Kitchen"
room["height"] = 2.7 # add a new key
print(room["height"],
      room["area"],
      room["floor"],
      room["name"])
# Out:
# 2.7 18.5 1 Kitchen

# %% [markdown]
# # functions

# %%
def r(width, depth, height):
    return width * depth * height
v=r(2.0, 3.0, 4.0)
print(f"The volume is {v} cubic units.")
# Out:
# The volume is 24.0 cubic units.
