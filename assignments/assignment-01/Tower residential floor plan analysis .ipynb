# %% [markdown]
# # Tower residential floor plan analysing

# %%
# This cell is not needed if you have pip installed topologicpy
import sys
sys.path.append("C:/Users/sarwj/OneDrive - Cardiff University/Documents/GitHub/topologicpy/src")

# %% [markdown]
# ## 1. Import the needed libraries

# %%
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Wire import Wire
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Grid import Grid
from topologicpy.Graph import Graph
from topologicpy.Color import Color

# %% [markdown]
# ## 2. Check the TopologicPy Version

# %%
print("This tutorial requires topologicpy version 0.9.18 or newer.")
print(Helper.Version())
# Out:
# This tutorial requires topologicpy version 0.9.18 or newer.
# The version that you are using (0.9.19) is OLDER than the latest version (0.9.21) from PyPI. Please consider upgrading to the latest version.

# %% [markdown]
# ## 3. Set your renderer:

# %%
renderer = "vscode"

# %% [markdown]
# ## 4. OBJ file as cluster

# %%
objects = Topology.ByOBJPath(r"C:\Users\merof\OneDrive\Desktop\GML.26\x.obj",
   selfMerge=True
)
cluster = Topology.Cells(objects[0])
rooms=CellComplex.ByCells(cluster)
Topology.Analyze(rooms)
#print(objects,Topology.Analyze(rooms))
# Out:
# 'OVERALL ANALYSIS\n================\nThe shape is a cellComplex.\nNumber of cells = 9\nNumber of shells = 9\nNumber of faces = 46\nNumber of wires = 46\nNumber of edges = 76\nNumber of vertices = 40\n\n\nINDIVIDUAL ANALYSIS\n================\nThe shape is a cellComplex.\nNumber of cells = 9\n================\n  The shape is a cell.\n  Number of shells = 1\n  ================\n    The shape is a shell.\n    Number of faces = 6\n    ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 4\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 4\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 4\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 4\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n       ...

# %%
g2 = Graph.ByTopology(rooms, direct=True)

# %%
vertices = Graph.Vertices(g2)
for v in vertices:
    d = Dictionary.ByKeysValues(["size", "color"], [18, "red"])
    v = Topology.SetDictionary(v, d)
edges = Graph.Edges(g2)
for e in edges:
    d = Dictionary.ByKeysValues(["width", "color"], [4, "black"])
    e = Topology.SetDictionary(e, d)

# %%
Topology.Show(cc, g2,
              vertexSizeKey="size",
              vertexColorKey="color",
              edgeWidthKey="width",
              edgeColorKey="color",
              faceOpacity=0.3,
              width=500,
              height=500,
              backgroundColor="white",
              renderer= renderer)
